# %%
# use as template for scope data, etc

# %%
from pandas import DataFrame, Series
from matplotlib import *
from numpy import *
import csv
import os

# %%
def process_csv(filename, exclude=2):
    exampleFile = open(filename, encoding='utf-8')
    exampleReader = csv.reader(exampleFile)
    exampleData = list(exampleReader)
    print(exampleData[1])
    exampleFile.close()
    return exampleData[exclude:]

# %%
data = process_csv("780Aself_heterodyne_20190412.csv")
# Out:
# ['Freq', '', 'Amp', '', 'Freq', '', 'Amp', '', '']

# %%
df = DataFrame(data)

# %%
xpts, ypts = df[[0,2]].astype(float).values.transpose()
x0 = xpts[where(ypts == max(ypts))[0]][0]

# %%
fig,ax = pyplot.subplots()
ax.set_title("780A Self-Heterodyne Measurement")
ax.set_xlabel("[MHz]")
ax.set_ylabel("[dBm]")
ax.plot((xpts-x0)/(1e6),ypts,c="purple")
pyplot.show()

# %%
# zoom in on peak?
