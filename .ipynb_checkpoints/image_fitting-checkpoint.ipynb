# %%
""" Image fitting with matplotlib
    Preston Huft, June 2019
"""

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np

# %%
im = img.imread(
    'C:\\Users\\gothr\\Documents\\Graduate Research\\gaussian_spot.png')
plt.imshow(im)

# %%
im.shape
# Out:
# (881, 877, 4)

# %%
imxy = im[:,:,0]
xdim,ydim = imxy.shape

xarr = np.empty(xdim,list)
yarr = np.empty(ydim,list)
for i in range(0,2):
    xarr[i]=imxy[i,:]
    yarr[i]=imxy[:,i]

# %%
# Out:
# 881

# %%
mat = np.array([[[1,2,3],[3,4,5]],[[4,5,6],[6,7,8]]])

# %%
mat
# Out:
# array([[[1, 2, 3],
#         [3, 4, 5]],
#
#        [[4, 5, 6],
#         [6, 7, 8]]])

# %%
mat[0]
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
 mat[1]
# Out:
# array([3, 4])

# %%
mat[:,0]
# Out:
# array([1, 3])

# %%
mat.shape
# Out:
# (2, 2, 3)

# %%
mat[:,:,1].shape
# Out:
# (2, 2)

# %%
xy = mat[:,:,1]

# %%
x = np.empty(2,list)
y = np.empty(2,list)
for i in range(0,2):
    x[i]=xy[i,:]
    y[i]=xy[:,i]

# %%
x,y
# Out:
# (array([array([2, 4]), array([5, 7])], dtype=object),
#  array([array([2, 5]), array([4, 7])], dtype=object))
