# %% [markdown]
# See "Analytical solution of the forced Duffing’s oscillator" by M. I. Qaisi. Equation numbers given below refer to those in the paper.

# %%
from numpy import *
import matplotlib.pyplot as plt

# %% [markdown]
# $\ddot{x}+\alpha x+\beta x^{3}=F \cos \omega_{f} t$

# %%
#eq 9


#eq 12
a_k2 = lambda w,k,alpha,ak,beta,bk,F,ck: \
        ((w**2*(k-1)**2-alpha)*ak-beta*bk+F*ck)/(k*(k+1)*w**2)


# can show that b1 = x0^3, then get a3,
# then know that x(t) = a1 + a2 sin(wt) + a3 sin^2(wt)+...
# compute x cubed, and get b2
# repeat this procedure

# %%
# the initial conditions

a1 = 0 # x0
a2 = 0 # v0/w

# %%
tpts = linspace(0,2*pi,100)
for i in range(8):
    plt.plot(tpts,sin(tpts)**(i+1),label=1+i)
plt.legend()
